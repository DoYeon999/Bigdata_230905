# %%
client_id='biIknxESRihB12F2b_XO'
client_secret='mTD98L6coq'

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import json
import urllib.request
client_id='biIknxESRihB12F2b_XO'
client_secret='mTD98L6coq'
encText = urllib.parse.quote("영화")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
# 요청 처리 정상 = 200
if(rescode==200):
    response_body = response.read()
    res_body=json.loads(response_body.decode('utf-8'))
    # str1=" "
    for item in res_body['items']:
        img_link_list.append(item['link'])
        print(img_link_list)
        # str1+=item['title']+" "
        # print(item['title'])
        # print(item['description'])
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 22
#      20     # str1=" "
#      21     for item in res_body['items']:
# ---> 22         img_link_list.append(item['link'])
#      23         print(img_link_list)
#      24         # str1+=item['title']+" "
#      25         # print(item['title'])
#      26         # print(item['description'])
#      27 else:
#
# NameError: name 'img_link_list' is not defined

# %%
from konlpy.tag import *
hannanum=Hannanum()
kkma=Kkma()
komoran=Komoran()
okt=Okt()

# %%
okt.nouns(str1[:100])
# Out:
# ['영화',
#  '콘크리트',
#  '유토피아',
#  '후기',
#  '이병헌',
#  '박서준',
#  '붐',
#  '이',
#  '기록',
#  '경신',
#  '중인',
#  '영화',
#  '영화',
#  '선라이즈',
#  '리뷰',
#  '주의']

# %%
# 한글 처리 작업
from nltk import Text
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 폰트 추출
fontname='c:/Windows/fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=fontname).get_name()
rc('font',family=font_name)

# %%
movie_test=Text(okt.nouns(str1))
movie_test.plot(30)
plt.show()

# %%
# 어떤 글자가 몇 번 나타나는지
mv=movie_test.vocab()
mv
# Out:
# FreqDist({'영화': 107, '출연': 23, '진': 22, '정보': 18, '후기': 13, '추천': 13, '리뷰': 11, '평점': 11, '줄거리': 11, '넷플릭스': 10, ...})

# %%
from wordcloud import WordCloud
from PIL import Image
import numpy as np

# 이미지 오픈
im=Image.open('data/emong.png')

# numpy 배열로 생성
mask_arr=np.array(im)
mask_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
wc=WordCloud(width=1000, height=1000, background_color='white', font_path=font_path,
             mask=mask_arr, random_state=0)
plt.imshow(wc.generate_from_frequencies(mv))
plt.axis('off')
plt.savefig('data/movie.png')
plt.show()

# %%
i=1
for link in img_link_list:
  save_name='data/images/img'+str(i)+'.jpg'

  try:
    urllib.request.urlretrive(link, save_name)
    i+=1

  except:
    print(link,'저장실패')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 i=1
# ----> 2 for link in img_link_list:
#       3   save_name='data/images/img'+str(i)+'.jpg'
#       5   try:
#
# NameError: name 'img_link_list' is not defined
